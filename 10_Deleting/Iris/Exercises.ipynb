# %% [markdown]
# # Iris

# %% [markdown]
# ### Introduction:
#
# This exercise may seem a little bit strange, but keep doing it.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data).

# %% [markdown]
# ### Step 3. Assign it to a variable called iris

# %%
iris = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')
iris
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %% [markdown]
# ### Step 4. Create columns for the dataset

# %%
# 1. sepal_length (in cm)
# 2. sepal_width (in cm)
# 3. petal_length (in cm)
# 4. petal_width (in cm)
# 5. class

iris.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             4.9          3.0           1.4          0.2     Iris-setosa
# 1             4.7          3.2           1.3          0.2     Iris-setosa
# 2             4.6          3.1           1.5          0.2     Iris-setosa
# 3             5.0          3.6           1.4          0.2     Iris-setosa
# 4             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 144           6.7          3.0           5.2          2.3  Iris-virginica
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %% [markdown]
# ### Step 5.  Is there any missing value in the dataframe?

# %%
iris.isnull().sum()

#iris.isnull().value_counts()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# class           0
# dtype: int64

# %% [markdown]
# ### Step 6.  Lets set the values of the rows 10 to 29 of the column 'petal_length' to NaN

# %%
iris.iloc[10:30, 2:3] = np.nan
iris.head(15)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width        class
# 0            4.9          3.0           1.4          0.2  Iris-setosa
# 1            4.7          3.2           1.3          0.2  Iris-setosa
# 2            4.6          3.1           1.5          0.2  Iris-setosa
# 3            5.0          3.6           1.4          0.2  Iris-setosa
# 4            5.4          3.9           1.7          0.4  Iris-setosa
# 5            4.6          3.4           1.4          0.3  Iris-setosa
# 6            5.0          3.4           1.5          0.2  Iris-setosa
# 7            4.4          2.9           1.4          0.2  Iris-setosa
# 8            4.9          3.1           1.5          0.1  Iris-setosa
# 9            5.4          3.7           1.5          0.2  Iris-setosa
# 10           4.8          3.4           NaN          0.2  Iris-setosa
# 11           4.8          3.0           NaN          0.1  Iris-setosa
# ...

# %% [markdown]
# ### Step 7. Good, now lets substitute the NaN values to 1.0

# %%
iris.petal_length = iris.petal_length.fillna(1.0)
iris.head(15)

#分组用均值填充
#iris.petal_length = iris.petal_length.fillna(iris.groupby('class')['petal_length'].mean())
# Out:
#     sepal_length  sepal_width  petal_length  petal_width        class
# 0            4.9          3.0           1.4          0.2  Iris-setosa
# 1            4.7          3.2           1.3          0.2  Iris-setosa
# 2            4.6          3.1           1.5          0.2  Iris-setosa
# 3            5.0          3.6           1.4          0.2  Iris-setosa
# 4            5.4          3.9           1.7          0.4  Iris-setosa
# 5            4.6          3.4           1.4          0.3  Iris-setosa
# 6            5.0          3.4           1.5          0.2  Iris-setosa
# 7            4.4          2.9           1.4          0.2  Iris-setosa
# 8            4.9          3.1           1.5          0.1  Iris-setosa
# 9            5.4          3.7           1.5          0.2  Iris-setosa
# 10           4.8          3.4           1.0          0.2  Iris-setosa
# 11           4.8          3.0           1.0          0.1  Iris-setosa
# ...

# %% [markdown]
# ### Step 8. Now let's delete the column class

# %%
del iris['class']
# iris = iris[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             4.9          3.0           1.4          0.2
# 1             4.7          3.2           1.3          0.2
# 2             4.6          3.1           1.5          0.2
# 3             5.0          3.6           1.4          0.2
# 4             5.4          3.9           1.7          0.4
# ..            ...          ...           ...          ...
# 144           6.7          3.0           5.2          2.3
# 145           6.3          2.5           5.0          1.9
# 146           6.5          3.0           5.2          2.0
# 147           6.2          3.4           5.4          2.3
# 148           5.9          3.0           5.1          1.8
#
# [149 rows x 4 columns]

# %% [markdown]
# ### Step 9.  Set the first 3 rows as NaN

# %%
iris.iloc[0:3, :] = np.nan
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             NaN          NaN           NaN          NaN
# 1             NaN          NaN           NaN          NaN
# 2             NaN          NaN           NaN          NaN
# 3             5.0          3.6           1.4          0.2
# 4             5.4          3.9           1.7          0.4
# ..            ...          ...           ...          ...
# 144           6.7          3.0           5.2          2.3
# 145           6.3          2.5           5.0          1.9
# 146           6.5          3.0           5.2          2.0
# 147           6.2          3.4           5.4          2.3
# 148           5.9          3.0           5.1          1.8
#
# [149 rows x 4 columns]

# %% [markdown]
# ### Step 10.  Delete the rows that have NaN

# %%
iris = iris.dropna(how='any')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 3             5.0          3.6           1.4          0.2
# 4             5.4          3.9           1.7          0.4
# 5             4.6          3.4           1.4          0.3
# 6             5.0          3.4           1.5          0.2
# 7             4.4          2.9           1.4          0.2
# ..            ...          ...           ...          ...
# 144           6.7          3.0           5.2          2.3
# 145           6.3          2.5           5.0          1.9
# 146           6.5          3.0           5.2          2.0
# 147           6.2          3.4           5.4          2.3
# 148           5.9          3.0           5.1          1.8
#
# [146 rows x 4 columns]

# %% [markdown]
# ### Step 11. Reset the index so it begins with 0 again

# %%
iris = iris.reset_index(drop = True)
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.0          3.6           1.4          0.2
# 1             5.4          3.9           1.7          0.4
# 2             4.6          3.4           1.4          0.3
# 3             5.0          3.4           1.5          0.2
# 4             4.4          2.9           1.4          0.2
# ..            ...          ...           ...          ...
# 141           6.7          3.0           5.2          2.3
# 142           6.3          2.5           5.0          1.9
# 143           6.5          3.0           5.2          2.0
# 144           6.2          3.4           5.4          2.3
# 145           5.9          3.0           5.1          1.8
#
# [146 rows x 4 columns]

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %% [markdown]
# ### 404 Finder

# %%
nun_m = 100
row = np.random.randint(0, iris.shape[0], size=nun_m)
col = np.random.randint(0, iris.shape[1], size=nun_m)

iris.values[row, col] = np.nan
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.0          3.6           1.4          0.2
# 1             NaN          3.9           1.7          0.4
# 2             4.6          NaN           1.4          0.3
# 3             5.0          3.4           1.5          NaN
# 4             4.4          2.9           1.4          0.2
# ..            ...          ...           ...          ...
# 141           6.7          3.0           5.2          2.3
# 142           6.3          2.5           NaN          NaN
# 143           NaN          3.0           5.2          2.0
# 144           6.2          3.4           5.4          2.3
# 145           5.9          3.0           5.1          1.8
#
# [146 rows x 4 columns]

# %%
list_404 = iris.isnull().stack().index.tolist()

for r, c in list_404:
    print(f'row:{r}, col:{c}')
# Out:
# row:0, col:sepal_length
# row:0, col:sepal_width
# row:0, col:petal_length
# row:0, col:petal_width
# row:1, col:sepal_length
# row:1, col:sepal_width
# row:1, col:petal_length
# row:1, col:petal_width
# row:2, col:sepal_length
# row:2, col:sepal_width
# row:2, col:petal_length
# row:2, col:petal_width
# row:3, col:sepal_length
# row:3, col:sepal_width
# row:3, col:petal_length
# row:3, col:petal_width
# row:4, col:sepal_length
# row:4, col:sepal_width
# row:4, col:petal_length
# row:4, col:petal_width
# row:5, col:sepal_length
# row:5, col:sepal_width
# row:5, col:petal_length
# row:5, col:petal_width
# row:6, col:sepal_length
# row:6, col:sepal_width
# row:6, col:petal_length
# row:6, col:petal_width
# row:7, col:sepal_length
# row:7, col:sepal_width
# row:7, col:petal_length
# row:7, col:petal_width
# row:8, col:sepal_length
# row:8, col:sepal_width
# row:8, col:petal_length
# row:8, col:petal_width
# row:9, col:sepal_length
# row:9, col:sepal_width
# row:9, col:petal_length
# ...
