# %% [markdown]
# *   **Observation** = **行** (Row) / 一条数据记录
# *   **Variable / Column** = **列** (Column) / 特征
# *   **Entry** = **条目** / 这一行的数据
# *   **Index** = **索引** / 行的编号（通常是 0, 1, 2...）
# *   **NaN / Null** = **空值** / 没填数据
# *   **Dataset / DataFrame** = **表格**

# %% [markdown]
# # Pandas 练习题 (Pandas Exercises)
#
# 厌倦了看一大堆教程却找不到地方**练手**？我决定创建这个仓库，专门用来提供练习题以巩固 Pandas 技能。
# 别误会，教程是很棒的资源，但**纸上得来终觉浅，绝知此事要躬行**（To learn is to do）。如果你不动手练，是学不会的。
#
# 这里包含三种不同类型的文件：
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;1. **练习说明 (Exercise instructions)**：这就是题目，你要做的地方。
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;2. **不含代码的答案 (Solutions without code)**：只有运行结果，没有代码。让你对照你的结果对不对，而不剧透代码。
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;3. **含代码和注释的答案 (Solutions with code and comments)**：最终的标准答案。
#
# **我的建议是：**
# 你可以先通过教程、视频或官方文档学习某个知识点，然后来做这里对应的练习。学一个知识点，练一部分题。
# **如果你卡住了，千万别直接看带代码的答案！**
# 先去看看“不含代码的答案”，对照一下期望的输出结果，然后尝试自己写出正确的代码。
#
# 非常欢迎大家提出建议或参与贡献。🙂 请提交 Issue 或 PR，并在其中说明具体的练习题以及你的问题或解决方案。
#
# # 课程目录 (Lessons)
#
# | | | |
# |:---:|:---:|:---:|
# | **[获取与了解数据 (Getting and knowing)](#getting-and-knowing)** | **[数据合并 (Merge)](#merge)** | **[时间序列 (Time Series)](#time-series)** |
# | **[筛选与排序 (Filtering and Sorting)](#filtering-and-sorting)** | **[统计 (Stats)](#stats)** | **[删除数据 (Deleting)](#deleting)** |
# | **[分组 (Grouping)](#grouping)** | **[可视化 (Visualization)](#visualization)** | 索引 (Indexing) |
# | **[Apply 函数应用 (Apply)](#apply)** | [创建 Series 和 DataFrame](#creating-series-and-dataframes) | 数据导出 (Exporting) |
#
# ### [获取与了解数据](https://github.com/guipsamora/pandas_exercises/tree/master/01_Getting_%26_Knowing_Your_Data)
# *(这是你的第一站，用来练习读取数据、查看数据基本信息)*
# - [ ] [Chipotle (墨西哥煎饼快餐数据)](https://github.com/guipsamora/pandas_exercises/tree/master/01_Getting_%26_Knowing_Your_Data/Chipotle)
# - [ ] [Occupation (职业数据)](https://github.com/guipsamora/pandas_exercises/tree/master/01_Getting_%26_Knowing_Your_Data/Occupation)
# - [ ] [World Food Facts (世界食品营养成分数据)](https://github.com/guipsamora/pandas_exercises/tree/master/01_Getting_%26_Knowing_Your_Data/World%20Food%20Facts)
#
# ### [筛选与排序](https://github.com/guipsamora/pandas_exercises/tree/master/02_Filtering_%26_Sorting)
# *(练习如何提取你需要的数据，比如“找出所有年龄大于30岁的人”)*
# - [ ] [Chipotle](https://github.com/guipsamora/pandas_exercises/tree/master/02_Filtering_%26_Sorting/Chipotle)
# - [ ] [Euro12 (2012欧洲杯数据)](https://github.com/guipsamora/pandas_exercises/tree/master/02_Filtering_%26_Sorting/Euro12)
# - [ ] [Fictional Army (虚构军队数据)](https://github.com/guipsamora/pandas_exercises/tree/master/02_Filtering_%26_Sorting/Fictional%20Army)
#
# ### [分组 (Grouping)](https://github.com/guipsamora/pandas_exercises/tree/master/03_Grouping)
# *(练习 groupby，比如“统计每个职业的平均年龄”)*
# - [ ] [Alcohol Consumption (酒精消费数据)](https://github.com/guipsamora/pandas_exercises/tree/master/03_Grouping/Alcohol_Consumption)
# - [ ] [Occupation](https://github.com/guipsamora/pandas_exercises/tree/master/03_Grouping/Occupation)
# - [ ] [Regiment (军团数据)](https://github.com/guipsamora/pandas_exercises/tree/master/03_Grouping/Regiment)
#
# ### [Apply 函数应用](https://github.com/guipsamora/pandas_exercises/tree/master/04_Apply)
# *(练习你最开始问的那个 apply 函数，自定义处理逻辑)*
# - [ ] [Students Alcohol Consumption](https://github.com/guipsamora/pandas_exercises/tree/master/04_Apply/Students_Alcohol_Consumption)
# - [ ] [US_Crime_Rates (美国犯罪率)](https://github.com/guipsamora/pandas_exercises/tree/master/04_Apply/US_Crime_Rates)
#
# ### [数据合并 (Merge)](https://github.com/guipsamora/pandas_exercises/tree/master/05_Merge)
# *(练习把两张表拼在一起)*
# - [ ] [Auto_MPG (汽车油耗)](https://github.com/guipsamora/pandas_exercises/tree/master/05_Merge/Auto_MPG)
# - [ ] [Fictitious Names](https://github.com/guipsamora/pandas_exercises/tree/master/05_Merge/Fictitous%20Names)
# - [ ] [House Market (房产市场)](https://github.com/guipsamora/pandas_exercises/tree/master/05_Merge/Housing%20Market)
#
# ### [统计 (Stats)](https://github.com/guipsamora/pandas_exercises/tree/master/06_Stats)
# - [ ] [US_Baby_Names (美国婴儿姓名)](https://github.com/guipsamora/pandas_exercises/tree/master/06_Stats/US_Baby_Names)
# - [ ] [Wind_Stats (风力统计)](https://github.com/guipsamora/pandas_exercises/tree/master/06_Stats/Wind_Stats)
#
# ### [可视化 (Visualization)](https://github.com/guipsamora/pandas_exercises/tree/master/07_Visualization)
# *(练习画图)*
# - [ ] [Chipotle](https://github.com/guipsamora/pandas_exercises/tree/master/07_Visualization/Chipotle)
# - [ ] [Titanic Disaster (泰坦尼克号灾难)](https://github.com/guipsamora/pandas_exercises/tree/master/07_Visualization/Titanic_Desaster)
# - [ ] [Scores](https://github.com/guipsamora/pandas_exercises/tree/master/07_Visualization/Scores)
# - [ ] [Online Retail (在线零售)](https://github.com/guipsamora/pandas_exercises/tree/master/07_Visualization/Online_Retail)
# - [ ] [Tips (小费数据)](https://github.com/guipsamora/pandas_exercises/tree/master/07_Visualization/Tips)
#
# ### [创建 Series 和 DataFrames](https://github.com/guipsamora/pandas_exercises/tree/master/08_Creating_Series_and_DataFrames)
# - [ ] [Pokemon (宝可梦)](https://github.com/guipsamora/pandas_exercises/tree/master/08_Creating_Series_and_DataFrames/Pokemon)
#
# ### [时间序列 (Time Series)](https://github.com/guipsamora/pandas_exercises/tree/master/09_Time_Series)
# - [ ] [Apple_Stock (苹果公司股价)](https://github.com/guipsamora/pandas_exercises/tree/master/09_Time_Series/Apple_Stock)
# - [ ] [Getting_Financial_Data](https://github.com/guipsamora/pandas_exercises/tree/master/09_Time_Series/Getting_Financial_Data)
# - [ ] [Investor_Flow_of_Funds_US](https://github.com/guipsamora/pandas_exercises/tree/master/09_Time_Series/Getting_Financial_Data)
#
# ### [删除数据 (Deleting)](https://github.com/guipsamora/pandas_exercises/tree/master/10_Deleting)
# - [ ] [Iris (鸢尾花数据集)](https://github.com/guipsamora/pandas_exercises/tree/master/10_Deleting/Iris)
# - [ ] [Wine (红酒数据集)](https://github.com/guipsamora/pandas_exercises/tree/master/10_Deleting/Wine)
#
# # 视频题解
#
# 数据科学家实际操作演示上述练习的视频教程：
# [Data Talks - Pandas Learning By Doing](https://www.youtube.com/watch?v=pu3IpU937xs&list=PLgJhDSE2ZLxaY_DigHeiIDC1cD09rXgJv)
